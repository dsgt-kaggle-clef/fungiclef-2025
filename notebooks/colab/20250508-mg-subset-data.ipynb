# %% [markdown]
# # Subset of data
# Notebook to get a subset of the dataset for experimentation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# navigate to fungiclef-2025 repo
# %cd /content/drive/MyDrive/fungiclef-2025/
# Out:
# /content/drive/MyDrive/fungiclef-2025

# %%
# !ls -la
# Out:
# total 15
# drwx------  7 root root 4096 May  5 21:32 data
# drwx------ 10 root root 4096 May  5 23:35 fungiclef-2025
# -rw-------  1 root root 2246 May  5 23:35 fungiclef-repo
# drwx------  3 root root 4096 May  8 02:14 model

# %%
import pandas as pd

data_path = '/content/drive/MyDrive/fungiclef-2025/data'
train_path = f"{data_path}/processed/train_serialized.parquet"

# read train dataframe
train_df = pd.read_parquet(train_path)
train_df.head(5)
# Out:
#     eventDate  year  month   day  \
# 0  2021-01-24  2021    1.0  24.0
# 1  2021-02-27  2021    2.0  27.0
# 2  2021-02-27  2021    2.0  27.0
# 3  2021-02-27  2021    2.0  27.0
# 4  2021-02-27  2021    2.0  27.0
#
#                                              habitat countryCode  \
# 0  Mixed woodland (with coniferous and deciduous ...          DK
# 1                                             garden          DK
# 2                                             garden          DK
# 3                                             garden          DK
# 4                                             garden          DK
#
#                            scientificName   kingdom      phylum  \
# 0  Xylohypha ferruginosa (Corda) S.Hughes     Fungi  Ascomycota
# 1            Comatricha alta Preuss, 1851  Protozoa   Mycetozoa
# 2            Comatricha alta Preuss, 1851  Protozoa   Mycetozoa
# 3            Comatricha alta Preuss, 1851  Protozoa   Mycetozoa
# ...

# %%
len(train_df)
# Out:
# 7819

# %%
# get subset of train dataframe and write as parquet
subset_df = train_df.head(700)
display(len(subset_df))

# write dataframe as parquet
subset_path = f"{data_path}/processed/subset_train_serialized.parquet"
subset_df.to_parquet(subset_path)
# Out:
# 700
